# %%
import numpy as np
import matplotlib.pyplot as  plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

# %%
print(" ===== ZOMATO SALES ANALYSIS =====")
# Out:
#  ===== ZOMATO SALES ANALYSIS =====

# %%
sales_data.shape
# Out:
# (5, 5)

# %%
sales_data[:3]
# Out:
# array([[     1, 150000, 180000, 220000, 250000],
#        [     2, 120000, 140000, 160000, 190000],
#        [     3, 200000, 230000, 260000, 300000]])

# %%
sales_data[0],[1]
# Out:
# (array([     1, 150000, 180000, 220000, 250000]), [1])

# %%
sales_data[0:3]
# Out:
# array([[     1, 150000, 180000, 220000, 250000],
#        [     2, 120000, 140000, 160000, 190000],
#        [     3, 200000, 230000, 260000, 300000]])

# %%
# total sales per year

# %%
sum_total = np.sum(sales_data, axis=0)

# %%
yearly_total = sum_total[1:4]

# %%
sum_total
# Out:
# array([     15,  810000,  945000, 1085000, 1240000])

# %%
yt = np.sum(sales_data[:,1:], axis=1)

# %%
yt
# Out:
# array([800000, 610000, 990000, 900000, 780000])

# %%
full_total = np.sum(yt)

# %%
full_total
# Out:
# np.int64(4080000)

# %%
# MINIMUM SALES PER RESTAURANT

# %%
min_sales = np.min(sales_data[:, 1:], axis=0)

# %% [markdown]
# min_sales

# %%
min_sales
# Out:
# array([120000, 140000, 160000, 190000])

# %%
#AVERAGE SALES PER RESTAURANT

# %%
avg_sales = np.mean(sales_data[:, 1:], axis=1)

# %%
avg_sales
# Out:
# array([200000., 152500., 247500., 225000., 195000.])

# %%
#cumulative sales

# %%
cumsum = np.cumsum(sales_data[:,1:],axis=1)

# %%
cumsum
# Out:
# array([[150000, 330000, 550000, 800000],
#        [120000, 260000, 420000, 610000],
#        [200000, 430000, 690000, 990000],
#        [180000, 390000, 630000, 900000],
#        [160000, 345000, 550000, 780000]])

# %%
new_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 new_sales
#
# NameError: name 'new_sales' is not defined

# %%
sales_data
# Out:
# array([[     1, 150000, 180000, 220000, 250000],
#        [     2, 120000, 140000, 160000, 190000],
#        [     3, 200000, 230000, 260000, 300000],
#        [     4, 180000, 210000, 240000, 270000],
#        [     5, 160000, 185000, 205000, 230000]])

# %%
plt.figure(figsize=(10,6))

# %%
plt.plot(np.mean(cumsum,axis=0))

# %%
plt.title("Average cumulative sales accross all restaurant")
# Out:
# Text(0.5, 1.0, 'Average cumulative sales accross all restaurant')

# %%
plt.xlabel("years")
# Out:
# Text(0.5, 0, 'years')

# %%
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.grid(True)

# %%
plt.show()

# %% [markdown]
# **VECTOR OPERATIONS**

# %%
vector1 = np.array([1,2,3,4])

# %%
vector2 = np.array([5,6,7,8])

# %%
print("Vector addition:",vector1+vector2)
# Out:
# Vector addition: [ 6  8 10 12]

# %%
print("Vector Multiplication:",vector1*vector2)
# Out:
# Vector Multiplication: [ 5 12 21 32]
